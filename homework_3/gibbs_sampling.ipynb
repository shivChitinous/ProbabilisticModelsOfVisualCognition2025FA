# %% [markdown]
# # Gibbs sampling
#
# Originally by Weichao Qiu.
#
# If you find this ipython notebook is unclear or contains bugs, please post it on Piazza.
# If there's an error says "something is undefined", please run the cell that contains the definition or use "menu -> cell -> run all above"

# %% [markdown]
# # Foreground/background classification.
#
# Here we consider a model for foreground/background classification that can include spatial context. Intuitively, neighboring pixels in the image are likely to belong to the same class, i.e. are likely to be either all background or all foreground. This is a form of prior knowledge, or natural statistic, which can be learnt by analyzing natural images.
#
# For pixel $i$, the foreground label is $ S_i = 1 $, and background label is $ S_i = -1 $.
#
# The prior term in the energy encourages neighbouring pixels to have the same intensity ($N(i)$ is the set of pixels neighboring $i$):
# $ E_p[S] = \gamma \sum_{i} \sum_{j \in N(i)} { - S_i S_j} $
#
# The data term is defined as:
#
# $ E_d[S, I] = \eta \sum_{i} (I_i - S_i)^2 $
#
#
# These two terms are combined to get the energy.
#
# $ E[S] = E_p[S] + E_d[S, I] $
#
# Then the posterior of the labeling $S$ given the image $I$ (with temperature parameter $T$) is
#
# $ P(S|I) = \frac{1}{Z} \exp\left( - \frac{E[S]}{T} \right) $

# %% [markdown]
# The block of code below initializes the ipython notebook

# %%
# Initiialization code
# %matplotlib inline
import numpy as np
# from pylab import imshow, show, get_cmap, imread, figure, subplots, title, subplot
import matplotlib.pyplot as plt
from numpy import random
import pylab as pl

# %% [markdown]
# The block of code below loads an image and normalizes it to the  range $[-1, 1]$.

# %%
image_path = 'data/gibbs/cat4.jpg'
im = plt.imread(image_path)
plt.imshow(im)

def myimshow(state):
    plt.imshow(state, interpolation='nearest')

# Preprocess image to range (-1, 1)
def preproc_data(im, scale=0.1, debug=False):
    import skimage.color
    import skimage.transform
    
    tinyim = skimage.transform.rescale(im, scale,channel_axis=-1)
    grayim = skimage.color.rgb2gray(tinyim)

    # Linear map the data to -1, 1
    scale = grayim.max() - grayim.min()
    data = 2 * (grayim - grayim.min()) / scale - 1
    if debug:
        print('original range:', grayim.min(), grayim.max())
        print('remapped range:', data.min(), data.max())

    return [data, tinyim]

[data, im] = preproc_data(im, debug=True) # data is normalized image
# Out:
# original range: 0.08029214998671057 0.9158716505325027
# remapped range: -1.0 1.0

# %% [markdown]
# The block of code below defines the neighborhood structure for the Gibbs sampler.

# %%
def getneighor(y, x, h, w): # get 4-side neighbor
    n = []
    if (x != 0): n.append((y, x-1))
    if (x != w-1): n.append((y, x+1))
    if (y != 0): n.append((y-1, x))
    if (y != h-1): n.append((y+1, x))
    return n

def poslist(h,w):
    '''Get point list of a grid'''
    pos = []
    for x in range(w):
        for y in range(h):
            pos.append((y, x))
    return pos

# %% [markdown]
# Define a utility function to compute energy.

# %%
def energy_prior(state, gamma):
    total = 0
    (h, w) = state.shape
    pos = poslist(h, w)
    for p in pos:
        neighbor = getneighor(p[0], p[1], h, w) # compute neighbor
        
        for n in neighbor:
            total += state[p[0]][p[1]] * state[n[0]][n[1]]
    E = - gamma * total
    return E
        
def energy_data(state, data, eta):
    E = eta * sum((data - state)**2)
    return E

def energy(state, data, gamma, eta):
    return energy_prior(state, gamma) + energy_data(state, data, eta)

# %% [markdown]
# Define the Gibbs sampler.

# %%
def gibbs_sampler(state, data, gamma, eta, debug=False): # 0/1 state
    (h, w) = state.shape
    new_state = state.copy()
    pos = poslist(h, w)
    for p in pos:
        neighbor_pos = getneighor(p[0], p[1], h, w)
        neighbor_value = [new_state[n[0]][n[1]] for n in neighbor_pos]

        tmp1 = -gamma * -1 * sum(neighbor_value) # x_i = -1
        tmp2 = -gamma * 1 * sum(neighbor_value) # x_i = 1
        
        # add data term
        v = data[p[0]][p[1]]
        tmp1 += eta * (v - (-1))**2 # x_i = -1
        tmp2 += eta * (v - 1)**2 #  x_i = 1
        
        tmp1 = np.exp(-tmp1)
        tmp2 = np.exp(-tmp2)

        p1 = tmp1 / (tmp1 + tmp2)
        prob = random.uniform() # roll a dice
        
        if (debug): print(p1)
        if (prob > p1):
            new_state[p[0]][p[1]] = 1
        else:
            new_state[p[0]][p[1]] = -1
    return new_state

# %% [markdown]
# # Animation: sample with data term included
# Run this demo below; make sure to watch the animation as it happens!

# %%
def single_run(data, gamma=1.0, eta=5.0, nsteps=1000, debug=False):
    (h, w) = data.shape
    # Initialize state randomly
    state = random.choice([-1, 1], size=(h, w))
    E = []
    for i in range(nsteps):
        state = gibbs_sampler(state, data, gamma, eta, debug)
        e = energy(state, data, gamma, eta)
        E.append(e)
        
        #myimshow(state)
        #pl.show()
    return (state, E, data)

# %%
def gibb_sampling_convergence(data, nsteps=100, gamma=20, eta=1, random_seed=1, animate=True):
    """
    Matches the original notebook behavior as closely as possible:
    - Uses numpy.random (via `from numpy import random`) style RNG
    - Keeps the same figure alive while updating
    - Does NOT modify fg with the mask unless you do it yourself
    Returns fg (same as your code), plus extras.
    """
    import numpy as np
    import matplotlib.pyplot as plt
    from IPython.display import display, clear_output
    import time
    from numpy import random  # IMPORTANT: mirrors the original intent

    random.seed(random_seed)

    (h, w) = data.shape
    mat = random.random((h, w))
    mat[mat > 0.5] = 1
    mat[mat <= 0.5] = -1
    random_state = mat

    init_state = random_state

    new_state = random_state.copy()
    E = [energy(init_state, data, gamma, eta)]

    if animate: 
        f, ax = plt.subplots(figsize = (5,4))
        im_plot = ax.imshow(new_state, interpolation="nearest")
        ax.axis("off")
        disp = display(f, display_id=True)
    
    for _ in range(nsteps):
        new_state = gibbs_sampler(new_state, data, gamma, eta)
        E.append(energy(new_state, data, gamma, eta))
        if animate:
            im_plot.set_data(new_state)
            disp.update(f)
            time.sleep(0.01)

    if animate:
        plt.close(f)
    fg = data.copy()  # EXACTLY like your original (no masking applied)

    mask = (new_state == 1)
    return fg, mask, new_state, np.array(E)

# %%
fg, mask, new_state, E = gibb_sampling_convergence(data, nsteps=100, gamma=20, eta=1, random_seed=1, animate=True)

import seaborn as sns
fig, ax = plt.subplots(2, 1, figsize=(5, 4), gridspec_kw={'height_ratios': [3, 1]})
ax[0].imshow(fg, cmap="gray", interpolation="nearest")
ax[0].imshow(mask, cmap="Reds", interpolation="nearest", alpha=0.5)
ax[0].set_title("Foreground");
ax[0].axis("off")
ax[1].plot(E, '.', markersize=5, alpha=0.1);
ax[1].set_xlabel("Iteration");
ax[1].set_ylabel("Energy");
sns.despine(ax=ax[1])
plt.savefig(f"results/gibbs_convergence_image_{image_path.split('/')[-1]}.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# # Questions: Gibbs sampler
# Set random_seed to a different value (and tell me what it is in your homework!)
# 1. Try a few different values of $ \gamma $, $ \eta $, including special case that only contains the prior term. What happens when the parameters change? (6 points)
# 2. Run with different images, plot your results. Find two or three images from the web or your image collection. Can you find an image that causes the model to identify the foreground poorly? Include the image that you use. (4 points)
# 3. Around what iteration does the sampler converge for the Einstein image with $ \gamma = 20 $ and $ \eta = 1 $ and how do you know it? Don't just say "the image stopped changing very much"! Hint: Check the energy of each state $S$.(6 points)

# %% [markdown]
# ## question 1

# %%
gammas = [20, 2, 0.2]
etas = [1, 0.5, 0]

fig, ax = plt.subplots(len(etas), len(gammas), figsize=(12, 8))
for eta in etas:
    for gamma in gammas:
        fg, mask, new_state, E = gibb_sampling_convergence(data, nsteps=100, gamma=gamma, eta=eta, random_seed=1, animate=False)
        ax_idx = (etas.index(eta), gammas.index(gamma))
        ax[ax_idx].imshow(fg, cmap="gray", interpolation="nearest")
        ax[ax_idx].imshow(mask, cmap="Reds", interpolation="nearest", alpha=0.5)
        ax[ax_idx].set_title(f"gamma={gamma}, eta={eta}")
        ax[ax_idx].axis("off")

plt.savefig(f"results/gibbs_convergence_image_multi_parameter_{image_path.split('/')[-1].split('.')[0]}.png", dpi=300, bbox_inches='tight')

# %%
gammas = [20, 2, 0.2]
etas = [0]

fig, ax = plt.subplots(len(etas), len(gammas), figsize=(12, 3))
for gamma in gammas:
    for eta in etas:
        fg, mask, new_state, E = gibb_sampling_convergence(-data, nsteps=100, gamma=gamma, eta=eta, random_seed=1, animate=False)
        ax_idx = (gammas.index(gamma))
        ax[ax_idx].imshow(fg, cmap="gray", interpolation="nearest")
        ax[ax_idx].imshow(mask, cmap="Reds", interpolation="nearest", alpha=0.5)
        ax[ax_idx].set_title(f"gamma={gamma}, eta={eta}")
        ax[ax_idx].axis("off")

plt.savefig(f"results/gibbs_convergence_image_multi_parameter_inverted_{image_path.split('/')[-1].split('.')[0]}.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## question 3

# %%
image_path = 'data/gibbs/gibbs_demo.jpg'
im = plt.imread(image_path)
[data, im] = preproc_data(im, debug=True) # data is normalized image
fg, mask, new_state, E = gibb_sampling_convergence(data, nsteps=100, gamma=20, eta=1, random_seed=1, animate=True)

fig, ax = plt.subplots(2, 1, figsize=(5, 4), gridspec_kw={'height_ratios': [3, 1]})
ax[0].imshow(fg, cmap="gray", interpolation="nearest")
ax[0].imshow(mask, cmap="Reds", interpolation="nearest", alpha=0.5)
ax[0].set_title("Foreground");
ax[0].axis("off")
ax[1].plot(E, '.', markersize=5, alpha=0.1);
ax[1].set_xlabel("Iteration");
ax[1].set_ylabel("Energy");
sns.despine(ax=ax[1])

percentage_change = 0.01
dE = np.abs(np.diff(E, axis=0, prepend=E[:1]))
cutoff = np.where(np.mean(dE[1:]/np.abs(E[1:])*100, axis=1)<percentage_change)[0][0]
ax[1].axvline(cutoff, color='red', linestyle='--', label=fr'average$({{|\Delta E|/|E|}}) \leq$ {percentage_change}%')
ax[1].text(cutoff+2, 0, f'{cutoff}', color='red')
ax[1].legend()

plt.savefig(f"results/gibbs_convergence_image_{image_path.split('/')[-1].split('.')[0]}.png", dpi=300, bbox_inches='tight')
# Out:
# original range: 2.6135007242304208e-08 0.8057972444297088
# remapped range: -1.0 1.0

# %% [markdown]
# ## question 2

# %%
image_path = 'data/gibbs/cajal.jpeg'
im = plt.imread(image_path)
[data, im] = preproc_data(im, debug=True, scale=0.3) # data is normalized image
fg, mask, new_state, E = gibb_sampling_convergence(-data, nsteps=100, gamma=20, eta=1, random_seed=1, animate=True)

fig, ax = plt.subplots(1, 2, figsize=(6, 4))
ax[0].imshow(fg, cmap="gray", interpolation="nearest")
ax[1].imshow(mask, cmap="Reds", interpolation="nearest", alpha=0.5)
ax[0].set_title("image");
ax[0].axis("off")
ax[1].set_title("mask");
ax[1].axis("off")

plt.savefig(f"results/gibbs_convergence_image_{image_path.split('/')[-1].split('.')[0]}.png", dpi=300, bbox_inches='tight')
# Out:
# original range: 0.17877228797951136 0.867665429080147
# remapped range: -1.0 1.0
